# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Dec 11 02:16:31 2020

@author: mtirrito
"""
from colorama import Fore, Back, Style
        
def unicodeSymbols():
	cuteCodes = [None] * 15
	cuteCodes[0] = '\U0001F384' ###Christmas Tree Icon ###
	cuteCodes[1] = '\U0001F385' ###Santa Claus Icon ###
	cuteCodes[2] = '\U0001F936' ###Mrs. Claus Icon ###
	cuteCodes[3] = '\U0001F31F' ###Christmas Star Icon ###
	cuteCodes[4] = '\U00002744' ###Christmas Snowflake Icon ###
	cuteCodes[5] = '\U000026C4' ###Large Snowman Icon ###
	cuteCodes[6] = '\U00002603' ###Small Snowman Icon ###
	cuteCodes[7] = '\U0001F381' ###Wrapped Present Icon ###
	cuteCodes[8] = '\U0001F514' ###Christmas Bell Icon ###
	cuteCodes[9] = '\U0001F3B6' ###Musical Note Icon ###
	cuteCodes[10] = '\U0001F56F'###Christmas Candle Icon ###
	cuteCodes[11] = '\U00002660'###Spade Icon ###
	cuteCodes[12] = '\U00002665'###Heart Icon ###
	cuteCodes[13] = '\U00002666'###Diamond Icon ###
	cuteCodes[14] = '\U00002663'###Club Icon ###	
	return cuteCodes

def tree(codes):
    
    print(Back.BLUE + Style.BRIGHT+"   "+codes[4]+"      "+codes[4]+"     "+codes[4]+"   "+codes[4]+"   "+codes[4]+Fore.RESET+Fore.YELLOW+" __/\__  "+Fore.RESET+codes[4]+"     "+codes[4]+"     "+codes[4]+"     "+codes[4]+"   "+codes[4]+"   "+codes[4]+"     "+codes[4]+"     "+codes[4]+"   "+ codes[4]+ "   "+codes[4]+"    ")
    
    
    print(" " +codes[4] +"      "  +codes[4] +"     " +codes[4] +"   " +codes[4] +"   " +codes[4] +Fore.YELLOW+'   \****/'  +Fore.WHITE+codes[4]  +"     "  +codes[4]  +"     " +codes[4] +"     " +codes[4] +"   " +codes[4] +"   "  +codes[4] +"     " +codes[4] +"     " +codes[4] +"   "  +codes[4]  +"   " +codes[4] +"     " +codes[4]) 
    
    print("   "    +codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "    +codes[4]    +Fore.YELLOW + " /****\   "    + Fore.WHITE+codes[4]     +"     "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   "    +codes[4]    +"  -")
    
    print(" "+ codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "    +codes[4]    +Fore.YELLOW+"   ``\/``  "     +Fore.WHITE+codes[4]     +"     "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   "    +codes[4]    +"   -")
    
    
    print("   "+ codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "    +codes[4]    + Fore.GREEN+"   /\     "     +Fore.WHITE+codes[4]     +"     "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   "    +codes[4]    +"  -")
		
    print("     " +codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"    "        +Fore.GREEN+"/" + Fore.MAGENTA + "@" + Fore.CYAN+ "@" + Fore.GREEN+"\    " + "  "     +Fore.WHITE+codes[4]     +"     "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"    "    +codes[4]    )
    
    
    
    print("   "     +codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "    +codes[4]    +Fore.GREEN+" ~~~~~~" + "  "     +Fore.WHITE+codes[4]     +"     "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   "    +codes[4]    +"  - ")
    
    
    print(" "    +codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "    +codes[4]    + Fore.GREEN+"  /"+Fore.RED+ "@"+Fore.YELLOW+"*"+Fore.CYAN+"@"+Fore.WHITE+"*"+Fore.MAGENTA+"@"+Fore.YELLOW+"*"+Fore.GREEN+"\""     +Fore.WHITE+"      "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   "    +codes[4]    +"    -")		
    
    
    print("   "    +codes[4]    +"      "     +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +" "    +codes[4]    +Fore.GREEN+" /"+Fore.YELLOW+"*"+Fore.RED+"@"+Fore.WHITE+"*"+Fore.CYAN+"@"+Fore.YELLOW+"*"+Fore.MAGENTA+"@"+Fore.WHITE+"*"+Fore.RED+"@"+Fore.GREEN+"\\"+"   "    +Fore.WHITE+codes[4]     +"     "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"    "    +codes[4])
    
    
    
    
    print(" "    +codes[4]    +"     "     +codes[4]    +"    "    +codes[4]    +"   "    +codes[4]    +"  "    +codes[4]    +Fore.GREEN+"   ~~~~~~~~~~~~    "     +Fore.WHITE+codes[4]    +"    "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   "    +codes[4])
    
    
    
    print("  "    +codes[4]    +"  "     +codes[4]    +"    "    +codes[4]    +"   "    +codes[4]    +"  "    +codes[4]    +Fore.GREEN+"    /"+Fore.CYAN+"@"+Fore.YELLOW+"*"+Fore.MAGENTA+"@"+Fore.WHITE+"*"+Fore.MAGENTA+"@"+Fore.YELLOW+"*"+Fore.CYAN+"@"+Fore.WHITE+"*"+Fore.RED+"@"+Fore.YELLOW+"*"+Fore.MAGENTA+"@"+Fore.WHITE+"*"+Fore.GREEN+"\     "     +Fore.WHITE+codes[4]     +"    "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"  ")
    
    
    
    print("   "   + codes[4]    +"  "     +codes[4]    +"    "    +codes[4]    +"   "    +codes[4]    +"  "    +codes[4]    +Fore.GREEN+"  /"+Fore.CYAN+"@"+Fore.YELLOW+"*"+Fore.RED+"@"+Fore.WHITE+"*"+Fore.MAGENTA+"@"+Fore.YELLOW+"*"+Fore.CYAN+"@"+Fore.WHITE+"*"+Fore.RED+"@"+Fore.YELLOW+"*"+Fore.MAGENTA+"@"+Fore.WHITE+"*"+Fore.CYAN+"@"+Fore.YELLOW+"*"+Fore.GREEN+"\   "     +Fore.WHITE+codes[4]     +"    "     +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"   ")
    
    
    
    print("   "     +codes[4]    +"  "     +codes[4]    +"    "    +codes[4]    +"   "    +codes[4]    +"    "        +Fore.GREEN+"~~~~~~~~~~~~~~~~~~   "    +Fore.WHITE+codes[4]     +'    '    +codes[4]     +"     "    +codes[4]    +"     "    +codes[4]    +"   "    +codes[4]    +"   "     +codes[4]    +"     "    +codes[4]    +"     "    +codes[4]    +"   "     +codes[4]     +"  ")  
    
        
        
+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"*"+"@"+"\                                    ")
    print("        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~                                   ")
    print(Fore.RED+"                          ///\\\\\\                                                     ")
    print("                         ////\\\\\\\\                                                    ")
    print("                        /////\\\\\\\\\\                                                   ")
    print("                       //////\\\\\\\\\\\\                                                  ")
    print("                      /~~~~~~~~~~~~\                                                 ")
    print("                     ----------------                                                ")
    print("                                                                                     ")
    print( "                                                                                     ")
	#end tree()method
    


def main():
     codes = unicodeSymbols()
     tree(codes)
     welcome(codes[7])
    
def welcome(symbol):
     # WE ARE GOING TO CREATE A BORDERED BANNER THAT USES THE SYMBOL PARAMETER FOR THE BORDER LINES.
    topBorder = ''
    bottomBorder = ''
    middleBorder=''
    
    for i in range(40):
        topBorder = topBorder + symbol#This is our top border line
    print(topBorder)
    middleBorder= topBorder
    bottomBorder = topBorder
    print(symbol + " Welcome to the Christmas Songs List Application v. 1.0                          " + symbol)
    print(symbol + " A Final Project For Fundamentals of Programming written in Python               " + symbol)
    print(middleBorder)
    print(symbol + " Final Project.py: Using the Python List of Lists (Two-Dimensional Array-Like    " + symbol)
    print(symbol + " Final Project.py: Using the Python List of Lists (Two-Dimensional Array-Like    " + symbol)
    print(symbol + "                   list) to create the Christmas Song Listing Application.       " + symbol)
    print(symbol + " Authored by: Your Student Name and Professor Tirrito                            " + symbol)
    print(symbol + " CMP131-83132 FA2020                                                             " + symbol)
    print(symbol + " County College of Morris                                                        " + symbol)
    print(symbol + " Professor Tirrito                                                               " + symbol)
    print(symbol + " Date Modified: 12/13/2020                                                       " + symbol)
    print(bottomBorder)
    print()
    #End of welcomeBanner function
     
main()
# Task one: Load current christmas songslist from textfile
def loadList():
    songsFile=open('songslist.txt','r')
    listList=eval(songsFile.read())
    songsFile.close()
    print(listList[0])
# Task one: Load specific christmas songslist from textfile
def specificList():
    try:
        songsFile=open('songslist.txt','r')
        songsList=eval(songsFile.read())
        songsFile.close()
        takelist=int(input('Please enter specific list Number to open '))
        print(songsList[takelist])
    except IndexError:
        print(f'Please enter between 0 to {len(songsList)-1}')

# Task one: Load current christmas songslist from textfile
def displayList():
    songsFile=open('songslist.txt','r')
    listList=eval(songsFile.read())
    songsFile.close()
    print(listList[0])
# Create a new christmas song list
def editList():
    #read the file and evaluate the list in the file
    songFile=open("songslist.txt","r")
    tempList=eval(songFile.read())
    songFile.close()
    listNumToEdit=int(input('Please enter the list number you want to edit'))
    titleofSong=input('please enter Title ')
    singerName=input('Please enter Singer name')
    song=input('Please enter Song')
    tempList[listNumToEdit]=[titleofSong,singerName,song]
    #append the new customer's details to the list then write the list back to the file
#     tempList.append()
    songFile=open("songslist.txt","w")
    songFile.write(str(tempList))
    songFile.close()
def addSongs():
    #Take their details
    title=input("What is the Title:\n")
    singer=input("What is the Singer's name:\n")
    song=input("Please enter the song:\n")        
    #Write to a list and then return this so it can be used by the fileWrite procedure>
    songList=[]
    songList.append(title)
    songList.append(singer)
    songList.append(song)
    global songDetails
    songDetails=songList
    return songList

# Save the christmas song list to original file
#Take the songList list as an arguement

def fileWrite(songDetails):
    #read the file and evaluate the list in the file
    songFile=open("songslist.txt","r")
    tempList=eval(songFile.read())
    songFile.close()
    #append the new customer's details to the list then write the list back to the file
    tempList.append(songDetails)
    songFile=open("songslist.txt","w")
    songFile.write(str(tempList))
    songFile.close()
# Save the christmas song list to a new file
def newFileWrite(songDetails):
    li=input('please write file name')
    txtnam=str(li+'.txt')
    with open(txtnam,'w') as newfile:
        newfile.write(str(songDetails))
        newfile.close()
# complete program
def main_menu():
    exitprogram=True
    while exitprogram:
        task=int(input('Please select from the following choices:\n \
        1. Load Current Christmas Song List from Text File\n \
        2. Load Specific Christmas Song List from Text File\n \
        3. Display Current Christmas Song List on Screen\n \
        4. Edit the Christmas Song List\n \
        5. Create a New Christmas Song List\n \
        6. Save the Christmas Song List to Original File\n \
        7. Save the Christmas Song List to a New File\n \
        8. Exit the Program\n'))
            
        if task==1:
            loadList()
        elif task==2:
            specificList()
        elif task==3:
            displayList()
        elif task==4:
            editList()
        elif task==5:
            addSongs()
        elif task==6:
            fileWrite(songDetails)
        elif task==7:
            newFileWrite(songDetails)            
        elif task==8:
            takeip=input("Are you sure you want to exit the program?\n please press\n y for yes\n n for no\n")
            if takeip=='n':
                print()
            elif takeip=='y':
                exitprogram=False
                print('Thanks for joining us')

            


        
main_menu()
# Out:
#    ❄      ❄     ❄   ❄   ❄ __/\__  ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄
#  ❄      ❄     ❄   ❄   ❄   \****/❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄     ❄
#    ❄      ❄     ❄   ❄   ❄ /****\   ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄  -
#  ❄      ❄     ❄   ❄   ❄   ``\/``  ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄   -
#    ❄      ❄     ❄   ❄   ❄   /\     ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄  -
#      ❄      ❄     ❄   ❄    /@@\      ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄    ❄
#    ❄      ❄     ❄   ❄   ❄ ~~~~~~  ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄  -
#  ❄      ❄     ❄   ❄   ❄  /@*@*@*"      ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄    -
#    ❄      ❄     ❄   ❄ ❄ /*@*@*@*@\   ❄     ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄    ❄
#  ❄     ❄    ❄   ❄  ❄   ~~~~~~~~~~~~    ❄    ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄   ❄
#   ❄  ❄    ❄   ❄  ❄    /@*@*@*@*@*@*\     ❄    ❄     ❄     ❄   ❄   ❄     ❄     ❄   ❄
# ...
